# %% [markdown]
# # 🐼 Colombian National Test `Saber 11` 🧾

# %% [markdown]
# ### Import Libraries

# %%
#==================================================================================
#Import Libraries
#==================================================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import statsmodels.api as sm
import seaborn as sns

#from scipy.stats import linregress
#from scipy.optimize import curve_fit
#from scipy.stats import pearsonr, f_oneway

#from sklearn.linear_model import Lasso, Ridge, LinearRegression, LogisticRegression
#from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, r2_score, accuracy_score, classification_report, roc_curve, roc_auc_score, auc
#from sklearn.metrics import precision_recall_curve
#from sklearn.metrics import average_precision_score

#from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler

# Imports several metrics for evaluating regression and classification models.
#from sklearn.metrics import precision_recall_fscore_support as score

# Used for data preprocessing and transformation
#from sklearn.preprocessing import StandardScaler, PolynomialFeatures, label_binarize, LabelEncoder

# A Pipeline is a sequence of steps for processing and transforming data
#from sklearn.pipeline import Pipeline

# A RandomTreeDecision
#from sklearn.tree import DecisionTreeRegressor
#from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### Read Data

# %%
#==================================================================================
#Read Data
#==================================================================================

Saber11 = pd.read_csv('SABER11_2020.csv', index_col=0, sep=';', encoding='latin-1')

Saber11_df = pd.DataFrame(Saber11)

Saber11_df
# Out:
#                    ESTU_NACIONALIDAD ESTU_GENERO  PERIODO ESTU_TIENEETNIA  \
# ESTU_TIPODOCUMENTO
# NaN                            SUIZA           F    20204              No
# NaN                        VENEZUELA           M    20204              No
# NaN                        VENEZUELA           F    20204              No
# NaN                        VENEZUELA           M    20204              No
# NaN                         COLOMBIA           F    20204              No
# ...                              ...         ...      ...             ...
# NaN                         COLOMBIA           M    20204              No
# NaN                         COLOMBIA           M    20204              No
# NaN                         COLOMBIA           F    20204              No
# NaN                         COLOMBIA           M    20204              No
# NaN                         COLOMBIA           F    20204              No
#
#                     ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# ESTU_TIPODOCUMENTO
# NaN                                  25.0                25126.0
# NaN                                  25.0                25126.0
# NaN                                  25.0                25126.0
# NaN                                  25.0                25126.0
# NaN                                  25.0                25126.0
# ...                                   ...                    ...
# NaN                                  11.0                11001.0
# NaN                                  11.0                11001.0
# NaN                                  11.0                11001.0
# NaN                                  11.0                11001.0
# NaN                                  11.0                11001.0
#
#                    FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR FAMI_CUARTOSHOGAR  \
# ESTU_TIPODOCUMENTO
# NaN                           Estrato 2              5 a 6               Dos
# NaN                           Estrato 3              3 a 4               Uno
# NaN                           Estrato 1              5 a 6               Uno
# NaN                         Sin Estrato              5 a 6               Dos
# NaN                           Estrato 5              5 a 6              Tres
# ...                                 ...                ...               ...
# NaN                           Estrato 2              5 a 6              Tres
# NaN                           Estrato 2              3 a 4               Dos
# NaN                           Estrato 2              5 a 6            Cuatro
# NaN                           Estrato 2              3 a 4              Tres
# NaN                           Estrato 3              3 a 4               Dos
#
#                                      FAMI_EDUCACIONPADRE  ...  \
# ESTU_TIPODOCUMENTO                                        ...
# NaN                       Técnica o tecnológica completa  ...
# NaN                   Secundaria (Bachillerato) completa  ...
# NaN                                  Primaria incompleta  ...
# NaN                 Secundaria (Bachillerato) incompleta  ...
# NaN                   Secundaria (Bachillerato) completa  ...
# ...                                                  ...  ...
# NaN                       Técnica o tecnológica completa  ...
# NaN                                  Primaria incompleta  ...
# NaN                                  Primaria incompleta  ...
# NaN                 Secundaria (Bachillerato) incompleta  ...
# NaN                   Secundaria (Bachillerato) completa  ...
#
#                    DESEMP_C_NATURALES PUNT_SOCIALES_CIUDADANAS  \
# ESTU_TIPODOCUMENTO
# NaN                                 2                       33
# NaN                                 2                       49
# NaN                                 3                       68
# NaN                                 2                       43
# NaN                                 2                       32
# ...                               ...                      ...
# NaN                                 3                       51
# NaN                                 1                       53
# NaN                                 3                       65
# NaN                                 2                       56
# NaN                                 2                       52
#
#                    PERCENTIL_SOCIALES_CIUDADANAS DESEMP_SOCIALES_CIUDADANAS  \
# ESTU_TIPODOCUMENTO
# NaN                                           11                          1
# NaN                                           55                          2
# NaN                                           95                          3
# NaN                                           38                          2
# NaN                                            7                          1
# ...                                          ...                        ...
# NaN                                           59                          2
# NaN                                           66                          2
# NaN                                           91                          3
# NaN                                           72                          3
# NaN                                           63                          2
#
#                    PUNT_INGLES PERCENTIL_INGLES DESEMP_INGLES PUNT_GLOBAL  \
# ESTU_TIPODOCUMENTO
# NaN                       55.0               81            A1         244
# NaN                       33.0                6            A-         238
# NaN                       59.0               87            A2         325
# NaN                       47.0               58            A-         238
# NaN                       43.0               40            A-         202
# ...                        ...              ...           ...         ...
# NaN                       45.0               52            A-         282
# NaN                       54.0               79            A1         257
# NaN                       67.0               93            A2         330
# NaN                       52.0               75            A1         290
# NaN                       48.0               63            A1         261
#
#                    PERCENTIL_GLOBAL         ESTU_GENERACION-E
# ESTU_TIPODOCUMENTO
# NaN                              49                        NO
# NaN                              44                        NO
# NaN                              94  GENERACION E - GRATUIDAD
# NaN                              45                        NO
# NaN                              19                        NO
# ...                             ...                       ...
# NaN                              75                        NO
# NaN                              59                        NO
# NaN                              95                        NO
# NaN                              80                        NO
# NaN                              61  GENERACION E - GRATUIDAD
#
# [504872 rows x 60 columns]

# %% [markdown]
# ## View about Dataset

# %%
Saber11_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 504872 entries, nan to nan
# Data columns (total 60 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ESTU_NACIONALIDAD              504872 non-null  object
#  1   ESTU_GENERO                    504864 non-null  object
#  2   PERIODO                        504872 non-null  int64
#  3   ESTU_TIENEETNIA                501879 non-null  object
#  4   ESTU_COD_RESIDE_DEPTO          504870 non-null  float64
#  5   ESTU_COD_RESIDE_MCPIO          504870 non-null  float64
#  6   FAMI_ESTRATOVIVIENDA           487920 non-null  object
#  7   FAMI_PERSONASHOGAR             489699 non-null  object
#  8   FAMI_CUARTOSHOGAR              489033 non-null  object
#  9   FAMI_EDUCACIONPADRE            491882 non-null  object
#  10  FAMI_EDUCACIONMADRE            491386 non-null  object
#  11  FAMI_TRABAJOLABORPADRE         485181 non-null  object
#  12  FAMI_TRABAJOLABORMADRE         487273 non-null  object
#  13  FAMI_TIENEINTERNET             491207 non-null  object
#  14  FAMI_TIENESERVICIOTV           489433 non-null  object
#  15  FAMI_TIENECOMPUTADOR           484678 non-null  object
#  16  FAMI_TIENELAVADORA             488640 non-null  object
#  17  FAMI_TIENEHORNOMICROOGAS       487730 non-null  object
#  18  FAMI_TIENEAUTOMOVIL            487063 non-null  object
#  19  FAMI_TIENEMOTOCICLETA          487786 non-null  object
#  20  FAMI_TIENECONSOLAVIDEOJUEGOS   487394 non-null  object
#  21  FAMI_NUMLIBROS                 491029 non-null  object
#  22  FAMI_COMELECHEDERIVADOS        491244 non-null  object
#  23  FAMI_COMECARNEPESCADOHUEVO     489566 non-null  object
#  24  FAMI_COMECEREALFRUTOSLEGUMBRE  484609 non-null  object
#  25  FAMI_SITUACIONECONOMICA        488558 non-null  object
#  26  ESTU_DEDICACIONLECTURADIARIA   490391 non-null  object
#  27  ESTU_DEDICACIONINTERNET        490246 non-null  object
#  28  ESTU_HORASSEMANATRABAJA        487888 non-null  object
#  29  ESTU_TIPOREMUNERACION          487226 non-null  object
#  30  COLE_COD_DEPTO_UBICACION       504872 non-null  int64
#  31  COLE_COD_MCPIO_UBICACION       504872 non-null  int64
#  32  COLE_GENERO                    504872 non-null  object
#  33  COLE_NATURALEZA                504872 non-null  object
#  34  COLE_CALENDARIO                504872 non-null  object
#  35  COLE_BILINGUE                  421865 non-null  object
#  36  COLE_CARACTER                  490695 non-null  object
#  37  COLE_SEDE_PRINCIPAL            504872 non-null  object
#  38  COLE_AREA_UBICACION            504872 non-null  object
#  39  COLE_JORNADA                   504872 non-null  object
#  40  COLE_COD_DEPTO_UBICACION.1     504872 non-null  int64
#  41  ESTU_PRIVADO_LIBERTAD          504872 non-null  object
#  42  PUNT_LECTURA_CRITICA           504872 non-null  int64
#  43  PERCENTIL_LECTURA_CRITICA      504872 non-null  int64
#  44  DESEMP_LECTURA_CRITICA         504872 non-null  int64
#  45  PUNT_MATEMATICAS               504872 non-null  int64
#  46  PERCENTIL_MATEMATICAS          504872 non-null  int64
#  47  DESEMP_MATEMATICAS             504872 non-null  int64
#  48  PUNT_C_NATURALES               504872 non-null  int64
#  49  PERCENTIL_C_NATURALES          504872 non-null  int64
#  50  DESEMP_C_NATURALES             504872 non-null  int64
#  51  PUNT_SOCIALES_CIUDADANAS       504872 non-null  int64
#  52  PERCENTIL_SOCIALES_CIUDADANAS  504872 non-null  int64
#  53  DESEMP_SOCIALES_CIUDADANAS     504872 non-null  int64
#  54  PUNT_INGLES                    504538 non-null  float64
#  55  PERCENTIL_INGLES               504872 non-null  int64
#  56  DESEMP_INGLES                  504872 non-null  object
#  57  PUNT_GLOBAL                    504872 non-null  int64
#  58  PERCENTIL_GLOBAL               504872 non-null  int64
#  59  ESTU_GENERACION-E              504872 non-null  object
# dtypes: float64(3), int64(19), object(38)
# memory usage: 235.0+ MB

# %%
print('Total instances: ', Saber11_df.shape[0]*Saber11_df.shape[1])
# Out:
# Total instances:  30292320

# %%
Saber11_df.columns # Show all dataset's columns
# Out:
# Index(['ESTU_NACIONALIDAD', 'ESTU_GENERO', 'PERIODO', 'ESTU_TIENEETNIA',
#        'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENELAVADORA',
#        'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
#        'ESTU_TIPOREMUNERACION', 'COLE_COD_DEPTO_UBICACION',
#        'COLE_COD_MCPIO_UBICACION', 'COLE_GENERO', 'COLE_NATURALEZA',
#        'COLE_CALENDARIO', 'COLE_BILINGUE', 'COLE_CARACTER',
#        'COLE_SEDE_PRINCIPAL', 'COLE_AREA_UBICACION', 'COLE_JORNADA',
#        'COLE_COD_DEPTO_UBICACION.1', 'ESTU_PRIVADO_LIBERTAD',
#        'PUNT_LECTURA_CRITICA', 'PERCENTIL_LECTURA_CRITICA',
#        'DESEMP_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PERCENTIL_MATEMATICAS',
#        'DESEMP_MATEMATICAS', 'PUNT_C_NATURALES', 'PERCENTIL_C_NATURALES',
#        'DESEMP_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS',
#        'PERCENTIL_SOCIALES_CIUDADANAS', 'DESEMP_SOCIALES_CIUDADANAS',
#        'PUNT_INGLES', 'PERCENTIL_INGLES', 'DESEMP_INGLES', 'PUNT_GLOBAL',
#        'PERCENTIL_GLOBAL', 'ESTU_GENERACION-E'],
#       dtype='object')

# %%
Subject_Results = ['ESTU_COD_RESIDE_DEPTO', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Subject_Results_df = Saber11_df[Subject_Results]    # Select only subject's score

Subject_Results_df
# Out:
#                     ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                                  25.0                    54
# NaN                                  25.0                    57
# NaN                                  25.0                    59
# NaN                                  25.0                    47
# NaN                                  25.0                    37
# ...                                   ...                   ...
# NaN                                  11.0                    60
# NaN                                  11.0                    57
# NaN                                  11.0                    78
# NaN                                  11.0                    69
# NaN                                  11.0                    58
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               65                41
# NaN                               43                46
# NaN                               72                63
# NaN                               55                46
# NaN                               48                44
# ...                              ...               ...
# NaN                               58                60
# NaN                               55                40
# NaN                               59                62
# NaN                               57                52
# NaN                               51                49
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       33         55.0          244
# NaN                                       49         33.0          238
# NaN                                       68         59.0          325
# NaN                                       43         47.0          238
# NaN                                       32         43.0          202
# ...                                      ...          ...          ...
# NaN                                       51         45.0          282
# NaN                                       53         54.0          257
# NaN                                       65         67.0          330
# NaN                                       56         52.0          290
# NaN                                       52         48.0          261
#
# [504872 rows x 7 columns]

# %% [markdown]
# ## General score description in Colombia

# %%
Subject_Results_df.describe()
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count          504870.000000         504872.000000     504872.000000
# mean               36.099671             52.156784         51.019754
# std               613.810991             10.158427         11.647657
# min                 5.000000              0.000000          0.000000
# 25%                11.000000             45.000000         43.000000
# 50%                20.000000             52.000000         51.000000
# 75%                54.000000             59.000000         59.000000
# max             99999.000000            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES  \
# count     504872.000000             504872.000000  504538.000000
# mean          48.197373                 48.233939      46.883507
# std           10.499610                 11.970584      11.313128
# min            0.000000                  0.000000       0.000000
# 25%           40.000000                 39.000000      39.000000
# 50%           48.000000                 47.000000      45.000000
# 75%           56.000000                 57.000000      52.000000
# max          100.000000                100.000000     100.000000
#
#          PUNT_GLOBAL
# count  504872.000000
# mean      248.347102
# std        48.692523
# min         0.000000
# 25%       211.000000
# 50%       245.000000
# 75%       282.000000
# max       500.000000

# %% [markdown]
# ## Focus on Quindío

# %%
Quindio_Subject_Results_df = Subject_Results_df.loc[(Subject_Results_df['ESTU_COD_RESIDE_DEPTO'] == '63') | (Subject_Results_df['ESTU_COD_RESIDE_DEPTO'] == 63)]  # Quindío Code = 63
print(Quindio_Subject_Results_df)
print(Quindio_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                                  63.0                    41
# NaN                                  63.0                    47
# NaN                                  63.0                    50
# NaN                                  63.0                    61
# NaN                                  63.0                    50
# ...                                   ...                   ...
# NaN                                  63.0                    54
# NaN                                  63.0                    66
# NaN                                  63.0                    60
# NaN                                  63.0                    58
# NaN                                  63.0                    64
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               50                43
# NaN                               42                46
# NaN                               45                46
# NaN                               59                59
# NaN                               49                49
# ...                              ...               ...
# NaN                               40                45
# NaN                               76                52
# NaN                               51                54
# NaN                               59                57
# NaN                               63                48
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       30         36.0          203
# NaN                                       51         43.0          231
# NaN                                       37         44.0          222
# NaN                                       65         44.0          298
# NaN                                       50         55.0          250
# ...                                      ...          ...          ...
# NaN                                       40         48.0          225
# NaN                                       65         49.0          318
# NaN                                       56         57.0          277
# NaN                                       60         49.0          289
# NaN                                       61         60.0          295
#
# [5810 rows x 7 columns]
# (5810, 7)

# %%
Quindio_Subject_Results_df.describe()   #Description about scores on Quindío
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                 5810.0           5810.000000       5810.000000
# mean                    63.0             53.389673         51.971773
# std                      0.0             10.078430         11.790968
# min                     63.0              0.000000          0.000000
# 25%                     63.0             46.000000         44.000000
# 50%                     63.0             54.000000         52.000000
# 75%                     63.0             61.000000         60.000000
# max                     63.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count       5810.000000               5810.000000  5810.000000  5810.000000
# mean          49.119621                 49.425818    48.020482   253.746127
# std           10.787960                 12.144625    11.206804    49.102446
# min            0.000000                  0.000000     0.000000     0.000000
# 25%           41.000000                 40.000000    40.000000   217.000000
# 50%           49.000000                 49.000000    46.000000   251.000000
# 75%           57.000000                 59.000000    54.000000   287.000000
# max          100.000000                100.000000   100.000000   462.000000

# %% [markdown]
# ## Focus on Antioquia

# %%
Antioquia_Subject_Results_df = Subject_Results_df.loc[(Subject_Results_df['ESTU_COD_RESIDE_DEPTO'] == '5') | (Subject_Results_df['ESTU_COD_RESIDE_DEPTO'] == 5)]  # Antioquia Code = 5
print(Antioquia_Subject_Results_df)
print(Antioquia_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                                   5.0                    66
# NaN                                   5.0                    50
# NaN                                   5.0                    57
# NaN                                   5.0                    44
# NaN                                   5.0                    54
# ...                                   ...                   ...
# NaN                                   5.0                    57
# NaN                                   5.0                    43
# NaN                                   5.0                    40
# NaN                                   5.0                    57
# NaN                                   5.0                    43
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               53                53
# NaN                               44                38
# NaN                               50                47
# NaN                               52                45
# NaN                               35                35
# ...                              ...               ...
# NaN                               61                49
# NaN                               33                34
# NaN                               40                31
# NaN                               56                44
# NaN                               29                33
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       56         40.0          278
# NaN                                       37         35.0          208
# NaN                                       55         42.0          257
# NaN                                       48         43.0          235
# NaN                                       46         35.0          210
# ...                                      ...          ...          ...
# NaN                                       49         58.0          272
# NaN                                       32         39.0          179
# NaN                                       34         36.0          181
# NaN                                       48         45.0          254
# NaN                                       41         39.0          183
#
# [70478 rows x 7 columns]
# (70478, 7)

# %%
Antioquia_Subject_Results_df.describe()   #Description about scores on Antioquia
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                70478.0          70478.000000      70478.000000
# mean                     5.0             51.852521         49.621825
# std                      0.0             10.338164         11.805077
# min                      5.0              0.000000          0.000000
# 25%                      5.0             44.000000         41.000000
# 50%                      5.0             52.000000         50.000000
# 75%                      5.0             59.000000         58.000000
# max                      5.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL
# count      70478.000000              70478.000000  70474.000000  70478.000000
# mean          46.621258                 47.838758     46.261543    243.870272
# std           10.445108                 12.083966     11.552551     48.935078
# min            0.000000                  0.000000      0.000000      0.000000
# 25%           39.000000                 38.000000     38.000000    206.000000
# 50%           46.000000                 47.000000     44.000000    240.000000
# 75%           54.000000                 57.000000     52.000000    278.000000
# max          100.000000                100.000000    100.000000    471.000000

# %% [markdown]
# ## Focus on Boyacá

# %%
Boyaca_Subject_Results_df = Subject_Results_df.loc[(Subject_Results_df['ESTU_COD_RESIDE_DEPTO'] == '15') | (Subject_Results_df['ESTU_COD_RESIDE_DEPTO'] == 15)]  # Boyacá Code = 15
print(Boyaca_Subject_Results_df)
print(Boyaca_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                                  15.0                    46
# NaN                                  15.0                    37
# NaN                                  15.0                    47
# NaN                                  15.0                    59
# NaN                                  15.0                    53
# ...                                   ...                   ...
# NaN                                  15.0                    47
# NaN                                  15.0                    70
# NaN                                  15.0                    57
# NaN                                  15.0                    39
# NaN                                  15.0                    53
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               32                45
# NaN                               39                46
# NaN                               50                47
# NaN                               47                53
# NaN                               39                47
# ...                              ...               ...
# NaN                               46                37
# NaN                               75                70
# NaN                               55                61
# NaN                               46                44
# NaN                               62                40
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       39         41.0          203
# NaN                                       33         44.0          196
# NaN                                       42         47.0          233
# NaN                                       48         47.0          257
# NaN                                       46         63.0          238
# ...                                      ...          ...          ...
# NaN                                       37         31.0          205
# NaN                                       77         71.0          364
# NaN                                       54         52.0          282
# NaN                                       47         39.0          218
# NaN                                       49         43.0          252
#
# [15258 rows x 7 columns]
# (15258, 7)

# %%
Boyaca_Subject_Results_df.describe()   #Description about scores on Boyacá
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                15258.0          15258.000000      15258.000000
# mean                    15.0             53.834316         54.336872
# std                      0.0              9.668379         11.026440
# min                     15.0              0.000000          0.000000
# 25%                     15.0             47.000000         47.000000
# 50%                     15.0             54.000000         55.000000
# 75%                     15.0             61.000000         62.000000
# max                     15.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL
# count      15258.000000              15258.000000  15258.000000  15258.000000
# mean          51.032835                 50.846048     47.961922    260.812230
# std            9.974170                 11.640947     10.585392     46.331506
# min            0.000000                  0.000000      0.000000      0.000000
# 25%           44.000000                 42.000000     41.000000    226.000000
# 50%           51.000000                 51.000000     47.000000    260.000000
# 75%           58.000000                 59.000000     53.000000    293.000000
# max          100.000000                100.000000    100.000000    468.000000

# %%
Saber11_df['ESTU_COD_RESIDE_MCPIO'].unique()
# Out:
# array([25126., 25785.,  5615., ..., 68895., 25878.,  5031.])

# %% [markdown]
# # Average score of Quindío by municipality

# %% [markdown]
# ## Armenia

# %%
Mun = ['ESTU_COD_RESIDE_MCPIO', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Quindio_Mun_Subject_df = Saber11_df[Mun]
Quindio_Armenia_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63001') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63001)]  # Select Armenia Code = 63001
print(Quindio_Armenia_Subject_Results_df)
print(Quindio_Armenia_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63001.0                    41
# NaN                               63001.0                    47
# NaN                               63001.0                    50
# NaN                               63001.0                    61
# NaN                               63001.0                    54
# ...                                   ...                   ...
# NaN                               63001.0                    49
# NaN                               63001.0                    74
# NaN                               63001.0                    61
# NaN                               63001.0                    60
# NaN                               63001.0                    64
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               50                43
# NaN                               42                46
# NaN                               45                46
# NaN                               59                59
# NaN                               50                43
# ...                              ...               ...
# NaN                               46                51
# NaN                               78                64
# NaN                               56                54
# NaN                               51                54
# NaN                               63                48
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       30         36.0          203
# NaN                                       51         43.0          231
# NaN                                       37         44.0          222
# NaN                                       65         44.0          298
# NaN                                       39         49.0          233
# ...                                      ...          ...          ...
# NaN                                       52         51.0          248
# NaN                                      100         73.0          393
# NaN                                       57         52.0          283
# NaN                                       56         57.0          277
# NaN                                       61         60.0          295
#
# [3049 rows x 7 columns]
# (3049, 7)

# %%
Quindio_Armenia_Subject_Results_df.describe()   # Score about Armenia
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                 3049.0           3049.000000       3049.000000
# mean                 63001.0             55.100689         53.960315
# std                      0.0             10.010298         11.982711
# min                  63001.0             27.000000          0.000000
# 25%                  63001.0             48.000000         45.000000
# 50%                  63001.0             55.000000         54.000000
# 75%                  63001.0             62.000000         62.000000
# max                  63001.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count       3049.000000               3049.000000  3049.000000  3049.000000
# mean          51.142342                 51.531978    50.105280   263.576910
# std           11.220327                 12.500304    11.965573    50.481254
# min           25.000000                 21.000000     0.000000   150.000000
# 25%           43.000000                 42.000000    42.000000   225.000000
# 50%           51.000000                 52.000000    48.000000   263.000000
# 75%           59.000000                 61.000000    56.000000   298.000000
# max          100.000000                100.000000   100.000000   462.000000

# %% [markdown]
# ## Buenavista

# %%
Quindio_Buenavista_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63111') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63111)]  # Select Armenia Code = 63001
print(Quindio_Buenavista_Subject_Results_df)
print(Quindio_Buenavista_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63111.0                    52
# NaN                               63111.0                    46
# NaN                               63111.0                    34
# NaN                               63111.0                    43
# NaN                               63111.0                    56
# NaN                               63111.0                    63
# NaN                               63111.0                    40
# NaN                               63111.0                    52
# NaN                               63111.0                    52
# NaN                               63111.0                    51
# NaN                               63111.0                    52
# NaN                               63111.0                    58
# NaN                               63111.0                    48
# NaN                               63111.0                    50
# NaN                               63111.0                    58
# NaN                               63111.0                    55
# NaN                               63111.0                    42
# NaN                               63111.0                    44
# NaN                               63111.0                    56
# NaN                               63111.0                    64
# NaN                               63111.0                    39
# NaN                               63111.0                    50
# NaN                               63111.0                    65
# NaN                               63111.0                    36
# NaN                               63111.0                    67
# NaN                               63111.0                    38
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               69                53
# NaN                               50                46
# NaN                               31                30
# NaN                               42                37
# NaN                               55                53
# NaN                               55                58
# NaN                               43                34
# NaN                               51                42
# NaN                               59                58
# NaN                               57                50
# NaN                               57                46
# NaN                               64                59
# NaN                               47                50
# NaN                               52                32
# NaN                               47                43
# NaN                               55                58
# NaN                               42                34
# NaN                               50                42
# NaN                               42                29
# NaN                               57                62
# NaN                               51                41
# NaN                               40                36
# NaN                               65                53
# NaN                               29                33
# NaN                               69                64
# NaN                               41                31
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       49         48.0          276
# NaN                                       57         37.0          244
# NaN                                       42         36.0          172
# NaN                                       51         36.0          213
# NaN                                       64         45.0          280
# NaN                                       54         47.0          283
# NaN                                       34         30.0          186
# NaN                                       39         48.0          231
# NaN                                       61         40.0          281
# NaN                                       53         48.0          262
# NaN                                       48         39.0          249
# NaN                                       58         52.0          296
# NaN                                       45         40.0          235
# NaN                                       51         44.0          230
# NaN                                       45         51.0          242
# NaN                                       63         45.0          284
# NaN                                       50         41.0          210
# NaN                                       42         32.0          218
# NaN                                       38         40.0          206
# NaN                                       61         53.0          302
# NaN                                       45         44.0          220
# NaN                                       34         55.0          206
# NaN                                       61         55.0          303
# NaN                                       33         47.0          169
# NaN                                       64         60.0          328
# NaN                                       36         35.0          182
# (26, 7)

# %%
Quindio_Buenavista_Subject_Results_df.describe()   # Score about Buenavista
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   26.0             26.000000         26.000000
# mean                 63111.0             50.423077         50.769231
# std                      0.0              9.170270         10.351068
# min                  63111.0             34.000000         29.000000
# 25%                  63111.0             43.250000         42.250000
# 50%                  63111.0             51.500000         51.000000
# 75%                  63111.0             56.000000         57.000000
# max                  63111.0             67.000000         69.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         26.000000                 26.000000    26.000000    26.000000
# mean          45.153846                 49.153846    44.153846   242.615385
# std           10.975217                 10.030722     7.587845    44.017339
# min           29.000000                 33.000000    30.000000   169.000000
# 25%           34.500000                 42.000000    39.250000   210.750000
# 50%           44.500000                 49.500000    44.500000   238.500000
# 75%           53.000000                 57.750000    48.000000   280.750000
# max           64.000000                 64.000000    60.000000   328.000000

# %% [markdown]
# ## Calarcá

# %%
Quindio_Calarca_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63130') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63130)]  # Select Calarca Code = 63130
print(Quindio_Calarca_Subject_Results_df)
print(Quindio_Calarca_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63130.0                    62
# NaN                               63130.0                    57
# NaN                               63130.0                    57
# NaN                               63130.0                    53
# NaN                               63130.0                    51
# ...                                   ...                   ...
# NaN                               63130.0                    72
# NaN                               63130.0                    42
# NaN                               63130.0                    56
# NaN                               63130.0                    68
# NaN                               63130.0                    58
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               66                56
# NaN                               50                54
# NaN                               39                41
# NaN                               47                41
# NaN                               50                46
# ...                              ...               ...
# NaN                               63                60
# NaN                               37                50
# NaN                               62                50
# NaN                               72                60
# NaN                               59                57
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       54         57.0          297
# NaN                                       57         42.0          268
# NaN                                       34         53.0          218
# NaN                                       44         36.0          227
# NaN                                       43         50.0          238
# ...                                      ...          ...          ...
# NaN                                       60         54.0          315
# NaN                                       59         55.0          238
# NaN                                       49         73.0          278
# NaN                                       53         43.0          308
# NaN                                       60         49.0          289
#
# [720 rows x 7 columns]
# (720, 7)

# %%
Quindio_Calarca_Subject_Results_df.describe()   # Score about Calarca
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  720.0            720.000000        720.000000
# mean                 63130.0             53.206944         52.247222
# std                      0.0              9.693937         11.387229
# min                  63130.0             28.000000         21.000000
# 25%                  63130.0             46.000000         44.000000
# 50%                  63130.0             54.000000         52.500000
# 75%                  63130.0             60.000000         60.000000
# max                  63130.0             77.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        720.000000                720.000000   720.000000   720.000000
# mean          48.466667                 49.041667    46.934722   252.236111
# std           10.255783                 11.434201    10.026247    46.307190
# min            0.000000                 21.000000     0.000000   103.000000
# 25%           41.000000                 40.000000    40.000000   217.000000
# 50%           48.000000                 49.000000    46.000000   250.500000
# 75%           56.000000                 57.000000    52.000000   285.000000
# max          100.000000                100.000000    83.000000   404.000000

# %% [markdown]
# ## Circasia

# %%
Quindio_Cicasia_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63190') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63190)]  # Select Calarca Code = 63190
print(Quindio_Cicasia_Subject_Results_df)
print(Quindio_Cicasia_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63190.0                    54
# NaN                               63190.0                    55
# NaN                               63190.0                    41
# NaN                               63190.0                    50
# NaN                               63190.0                    71
# ...                                   ...                   ...
# NaN                               63190.0                    53
# NaN                               63190.0                    53
# NaN                               63190.0                    51
# NaN                               63190.0                    50
# NaN                               63190.0                    30
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               49                53
# NaN                               66                65
# NaN                               42                37
# NaN                               44                41
# NaN                               61                56
# ...                              ...               ...
# NaN                               49                52
# NaN                               57                50
# NaN                               49                49
# NaN                               47                46
# NaN                               40                44
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       61         60.0          273
# NaN                                       61         58.0          307
# NaN                                       53         43.0          216
# NaN                                       37         73.0          227
# NaN                                       55         58.0          303
# ...                                      ...          ...          ...
# NaN                                       56         49.0          261
# NaN                                       59         49.0          272
# NaN                                       41         41.0          235
# NaN                                       46         31.0          230
# NaN                                       34         41.0          187
#
# [266 rows x 7 columns]
# (266, 7)

# %%
Quindio_Cicasia_Subject_Results_df.describe()   # Score about Calarca
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  266.0            266.000000        266.000000
# mean                 63190.0             52.067669         50.007519
# std                      0.0              9.816579         11.108383
# min                  63190.0             28.000000         22.000000
# 25%                  63190.0             45.000000         42.000000
# 50%                  63190.0             53.000000         50.000000
# 75%                  63190.0             59.000000         57.000000
# max                  63190.0             74.000000         77.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        266.000000                266.000000   266.000000   266.000000
# mean          48.041353                 48.469925    46.939850   247.210526
# std            9.984241                 11.397163     9.405145    45.079477
# min           27.000000                 22.000000    30.000000   156.000000
# 25%           40.000000                 39.000000    41.000000   211.250000
# 50%           48.000000                 49.000000    46.000000   246.000000
# 75%           55.000000                 57.000000    52.000000   279.000000
# max           74.000000                 74.000000    77.000000   362.000000

# %% [markdown]
# ## Córdoba

# %%
Quindio_Cordoba_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63212') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63212)]  # Select Córdoba Code = 63212
print(Quindio_Cordoba_Subject_Results_df)
print(Quindio_Cordoba_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63212.0                    35
# NaN                               63212.0                    41
# NaN                               63212.0                    36
# NaN                               63212.0                    50
# NaN                               63212.0                    57
# ...                                   ...                   ...
# NaN                               63212.0                    60
# NaN                               63212.0                    46
# NaN                               63212.0                    45
# NaN                               63212.0                    48
# NaN                               63212.0                    45
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               46                42
# NaN                               32                36
# NaN                               45                42
# NaN                               52                52
# NaN                               59                55
# ...                              ...               ...
# NaN                               58                62
# NaN                               49                39
# NaN                               37                30
# NaN                               39                50
# NaN                               38                38
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       31         43.0          194
# NaN                                       30         46.0          178
# NaN                                       30         41.0          192
# NaN                                       51         50.0          256
# NaN                                       57         55.0          284
# ...                                      ...          ...          ...
# NaN                                       56         68.0          298
# NaN                                       44         43.0          222
# NaN                                       38         47.0          191
# NaN                                       33         50.0          215
# NaN                                       37         37.0          197
#
# [75 rows x 7 columns]
# (75, 7)

# %%
Quindio_Cordoba_Subject_Results_df.describe()   # Score about Córdoba
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   75.0             75.000000         75.000000
# mean                 63212.0             47.200000         45.720000
# std                      0.0              8.277289          8.406175
# min                  63212.0             26.000000         28.000000
# 25%                  63212.0             40.000000         39.000000
# 50%                  63212.0             48.000000         45.000000
# 75%                  63212.0             54.000000         51.500000
# max                  63212.0             63.000000         66.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         75.000000                 75.000000    75.000000    75.000000
# mean          41.400000                 42.213333    43.600000   220.453333
# std            8.432562                  8.104542     6.898884    33.249789
# min           25.000000                 27.000000    29.000000   147.000000
# 25%           35.000000                 37.000000    39.000000   192.000000
# 50%           40.000000                 42.000000    43.000000   222.000000
# 75%           49.500000                 49.000000    48.000000   246.000000
# max           62.000000                 58.000000    68.000000   298.000000

# %% [markdown]
# ## Filandia

# %%
Quindio_Filandia_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63272') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63272)]  # Select Filandia Code = 63272
print(Quindio_Filandia_Subject_Results_df)
print(Quindio_Filandia_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63272.0                    57
# NaN                               63272.0                    49
# NaN                               63272.0                    51
# NaN                               63272.0                    46
# NaN                               63272.0                    41
# ...                                   ...                   ...
# NaN                               63272.0                    62
# NaN                               63272.0                    55
# NaN                               63272.0                    32
# NaN                               63272.0                    58
# NaN                               63272.0                    53
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               49                52
# NaN                               27                38
# NaN                               62                53
# NaN                               54                47
# NaN                               35                43
# ...                              ...               ...
# NaN                               68                65
# NaN                               60                52
# NaN                               28                27
# NaN                               55                52
# NaN                               62                58
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       45         41.0          250
# NaN                                       24         43.0          176
# NaN                                       63         56.0          286
# NaN                                       50         38.0          242
# NaN                                       51         38.0          211
# ...                                      ...          ...          ...
# NaN                                       62         55.0          318
# NaN                                       59         48.0          279
# NaN                                       37         42.0          159
# NaN                                       56         51.0          275
# NaN                                       54         50.0          281
#
# [166 rows x 7 columns]
# (166, 7)

# %%
Quindio_Filandia_Subject_Results_df.describe()   # Score about Filandia
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  166.0            166.000000        166.000000
# mean                 63272.0             50.921687         50.969880
# std                      0.0             10.167084         11.760965
# min                  63272.0             28.000000         26.000000
# 25%                  63272.0             43.000000         44.000000
# 50%                  63272.0             51.000000         52.000000
# 75%                  63272.0             58.750000         58.000000
# max                  63272.0             76.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        166.000000                166.000000   166.000000   166.000000
# mean          48.638554                 47.608434    45.873494   246.271084
# std           10.240831                 11.187533     9.968539    46.244987
# min           27.000000                 20.000000     0.000000   143.000000
# 25%           41.000000                 40.000000    39.000000   211.000000
# 50%           48.500000                 48.000000    44.000000   246.000000
# 75%           56.000000                 55.000000    51.000000   280.000000
# max           76.000000                 73.000000    80.000000   394.000000

# %% [markdown]
# ## Génova

# %%
Quindio_Genova_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63302') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63302)]  # Select Génova Code = 63302
print(Quindio_Genova_Subject_Results_df)
print(Quindio_Genova_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63302.0                    56
# NaN                               63302.0                    48
# NaN                               63302.0                    40
# NaN                               63302.0                    64
# NaN                               63302.0                    32
# ...                                   ...                   ...
# NaN                               63302.0                    48
# NaN                               63302.0                    58
# NaN                               63302.0                    49
# NaN                               63302.0                    55
# NaN                               63302.0                    42
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               30                50
# NaN                               48                48
# NaN                               45                41
# NaN                               55                57
# NaN                               38                34
# ...                              ...               ...
# NaN                               42                49
# NaN                               56                49
# NaN                               55                62
# NaN                               54                63
# NaN                               40                37
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       44         31.0          220
# NaN                                       41         43.0          230
# NaN                                       43         34.0          208
# NaN                                       66         58.0          302
# NaN                                       44         29.0          182
# ...                                      ...          ...          ...
# NaN                                       40         42.0          223
# NaN                                       61         59.0          281
# NaN                                       44         38.0          257
# NaN                                       58         50.0          285
# NaN                                       32         35.0          188
#
# [75 rows x 7 columns]
# (75, 7)

# %%
Quindio_Genova_Subject_Results_df.describe()   # Score about Filandia
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   75.0             75.000000         75.000000
# mean                 63302.0             49.266667         45.840000
# std                      0.0              9.601989         10.988987
# min                  63302.0             29.000000         23.000000
# 25%                  63302.0             43.000000         39.500000
# 50%                  63302.0             48.000000         45.000000
# 75%                  63302.0             56.000000         52.000000
# max                  63302.0             72.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         75.000000                 75.000000    75.000000    75.000000
# mean          45.866667                 45.400000    42.266667   231.346667
# std            9.604804                 11.324453     9.239067    44.685233
# min           26.000000                 22.000000    29.000000   162.000000
# 25%           38.500000                 36.500000    36.000000   198.000000
# 50%           45.000000                 44.000000    40.000000   223.000000
# 75%           52.000000                 54.500000    46.500000   267.500000
# max           76.000000                 71.000000    84.000000   400.000000

# %% [markdown]
# ## La Tebaida

# %%
Quindio_Tebaida_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63401') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63401)]  # Select Tebaida Code = 63401
print(Quindio_Tebaida_Subject_Results_df)
print(Quindio_Tebaida_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63401.0                    50
# NaN                               63401.0                    40
# NaN                               63401.0                    50
# NaN                               63401.0                    51
# NaN                               63401.0                    36
# ...                                   ...                   ...
# NaN                               63401.0                    50
# NaN                               63401.0                    42
# NaN                               63401.0                    39
# NaN                               63401.0                    57
# NaN                               63401.0                    66
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               58                48
# NaN                               45                45
# NaN                               54                46
# NaN                               32                44
# NaN                               35                32
# ...                              ...               ...
# NaN                               44                40
# NaN                               40                26
# NaN                               46                34
# NaN                               55                48
# NaN                               76                52
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       47         42.0          250
# NaN                                       39         47.0          213
# NaN                                       54         46.0          253
# NaN                                       40         38.0          207
# NaN                                       36         46.0          178
# ...                                      ...          ...          ...
# NaN                                       36         33.0          209
# NaN                                       34         41.0          180
# NaN                                       33         31.0          187
# NaN                                       58         28.0          262
# NaN                                       65         49.0          318
#
# [455 rows x 7 columns]
# (455, 7)

# %%
Quindio_Tebaida_Subject_Results_df.describe()   # Score about Tebaida
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  455.0            455.000000        455.000000
# mean                 63401.0             49.868132         47.279121
# std                      0.0              9.588458          9.844110
# min                  63401.0             28.000000          0.000000
# 25%                  63401.0             43.000000         41.000000
# 50%                  63401.0             50.000000         47.000000
# 75%                  63401.0             56.500000         54.000000
# max                  63401.0             77.000000         76.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        455.000000                455.000000   455.000000   455.000000
# mean          44.380220                 44.338462    43.628571   231.230769
# std            8.729314                 10.741032     8.569260    40.265385
# min            0.000000                 22.000000    28.000000   115.000000
# 25%           38.000000                 36.000000    38.000000   199.000000
# 50%           44.000000                 43.000000    43.000000   228.000000
# 75%           50.000000                 52.000000    49.000000   259.000000
# max           67.000000                 71.000000    76.000000   351.000000

# %% [markdown]
# ## Montenegro

# %%
Quindio_Montenegro_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63470') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63470)]  # Select Montenegro Code = 63470
print(Quindio_Montenegro_Subject_Results_df)
print(Quindio_Montenegro_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63470.0                    60
# NaN                               63470.0                    52
# NaN                               63470.0                    64
# NaN                               63470.0                    59
# NaN                               63470.0                    49
# ...                                   ...                   ...
# NaN                               63470.0                    39
# NaN                               63470.0                    54
# NaN                               63470.0                    55
# NaN                               63470.0                    38
# NaN                               63470.0                    60
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               58                50
# NaN                               50                49
# NaN                               46                44
# NaN                               51                56
# NaN                               36                43
# ...                              ...               ...
# NaN                               38                49
# NaN                               55                46
# NaN                               45                49
# NaN                               38                36
# NaN                               54                47
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       65         67.0          295
# NaN                                       49         44.0          248
# NaN                                       56         38.0          257
# NaN                                       58         55.0          280
# NaN                                       34         44.0          204
# ...                                      ...          ...          ...
# NaN                                       36         43.0          203
# NaN                                       53         56.0          262
# NaN                                       53         38.0          248
# NaN                                       32         35.0          180
# NaN                                       50         43.0          260
#
# [411 rows x 7 columns]
# (411, 7)

# %%
Quindio_Montenegro_Subject_Results_df.describe()   # Score about Montenegro
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  411.0            411.000000        411.000000
# mean                 63470.0             50.732360         49.024331
# std                      0.0              9.711266         11.208420
# min                  63470.0              0.000000          0.000000
# 25%                  63470.0             44.000000         41.500000
# 50%                  63470.0             52.000000         50.000000
# 75%                  63470.0             58.000000         57.000000
# max                  63470.0             76.000000         80.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        411.000000                411.000000   411.000000   411.000000
# mean          45.630170                 45.712895    45.133820   237.868613
# std            9.456677                 11.078228    10.463367    44.825214
# min            0.000000                  0.000000     0.000000     0.000000
# 25%           39.000000                 37.000000    38.000000   206.000000
# 50%           46.000000                 45.000000    44.000000   235.000000
# 75%           52.000000                 54.000000    51.000000   270.000000
# max           72.000000                 74.000000    79.000000   358.000000

# %% [markdown]
# ## Pijao

# %%
Quindio_Pijao_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63548') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63548)]  # Select Pijao Code = 63548
print(Quindio_Pijao_Subject_Results_df)
print(Quindio_Pijao_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63548.0                    64
# NaN                               63548.0                    49
# NaN                               63548.0                    68
# NaN                               63548.0                    60
# NaN                               63548.0                    64
# ...                                   ...                   ...
# NaN                               63548.0                    64
# NaN                               63548.0                    52
# NaN                               63548.0                    60
# NaN                               63548.0                    64
# NaN                               63548.0                    54
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               60                51
# NaN                               56                56
# NaN                               57                70
# NaN                               57                52
# NaN                               63                61
# ...                              ...               ...
# NaN                               57                62
# NaN                               50                47
# NaN                               52                46
# NaN                               62                65
# NaN                               40                45
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       67         41.0          295
# NaN                                       35         44.0          243
# NaN                                       65         63.0          324
# NaN                                       61         49.0          284
# NaN                                       62         52.0          308
# ...                                      ...          ...          ...
# NaN                                       59         65.0          304
# NaN                                       37         48.0          233
# NaN                                       43         38.0          247
# NaN                                       71         48.0          321
# NaN                                       40         48.0          225
#
# [98 rows x 7 columns]
# (98, 7)

# %%
Quindio_Pijao_Subject_Results_df.describe()   # Score about Pijao
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   98.0             98.000000         98.000000
# mean                 63548.0             52.500000         50.051020
# std                      0.0              9.377809         11.661349
# min                  63548.0             31.000000         19.000000
# 25%                  63548.0             48.000000         45.000000
# 50%                  63548.0             52.000000         51.500000
# 75%                  63548.0             58.750000         57.000000
# max                  63548.0             76.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         98.000000                 98.000000    98.000000    98.000000
# mean          48.510204                 48.214286    46.836735   247.938776
# std            9.378903                 10.522680     9.676940    43.658897
# min           25.000000                 28.000000    30.000000   149.000000
# 25%           43.000000                 40.000000    40.250000   225.250000
# 50%           48.000000                 47.000000    46.000000   244.500000
# 75%           54.000000                 56.000000    51.500000   274.500000
# max           70.000000                 71.000000    74.000000   372.000000

# %% [markdown]
# ## Quimbaya

# %%
Quindio_Quimbaya_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63594') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63594)]  # Select Quimbaya Code = 63594
print(Quindio_Quimbaya_Subject_Results_df)
print(Quindio_Quimbaya_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63594.0                    43
# NaN                               63594.0                    49
# NaN                               63594.0                    51
# NaN                               63594.0                    37
# NaN                               63594.0                    57
# ...                                   ...                   ...
# NaN                               63594.0                    49
# NaN                               63594.0                    67
# NaN                               63594.0                    45
# NaN                               63594.0                    55
# NaN                               63594.0                    69
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               50                48
# NaN                               43                47
# NaN                               53                47
# NaN                               37                36
# NaN                               57                53
# ...                              ...               ...
# NaN                               58                45
# NaN                               71                67
# NaN                               31                46
# NaN                               49                52
# NaN                               57                52
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       41         41.0          226
# NaN                                       47         38.0          229
# NaN                                       51         70.0          260
# NaN                                       37         30.0          181
# NaN                                       46         47.0          264
# ...                                      ...          ...          ...
# NaN                                       50         62.0          257
# NaN                                       61         50.0          326
# NaN                                       35         43.0          198
# NaN                                       38         44.0          241
# NaN                                       54         51.0          287
#
# [383 rows x 7 columns]
# (383, 7)

# %%
Quindio_Quimbaya_Subject_Results_df.describe()   # Score about Quimbaya
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  383.0            383.000000        383.000000
# mean                 63594.0             51.825065         49.916449
# std                      0.0              9.921324         11.236082
# min                  63594.0             27.000000         21.000000
# 25%                  63594.0             44.000000         42.000000
# 50%                  63594.0             52.000000         50.000000
# 75%                  63594.0             59.000000         58.000000
# max                  63594.0            100.000000         81.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        383.000000                383.000000   383.000000   383.000000
# mean          47.733681                 47.678851    46.712794   245.456919
# std            9.684396                 11.584145    10.455892    45.575352
# min           28.000000                 22.000000    28.000000   149.000000
# 25%           41.000000                 39.000000    39.000000   210.500000
# 50%           47.000000                 47.000000    45.000000   241.000000
# 75%           54.000000                 55.000000    52.000000   274.500000
# max           77.000000                100.000000    81.000000   391.000000

# %% [markdown]
# ## Salento

# %%
Quindio_Salento_Subject_Results_df = Quindio_Mun_Subject_df.loc[(Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == '63690') | (Quindio_Mun_Subject_df['ESTU_COD_RESIDE_MCPIO'] == 63690)]  # Select Salento Code = 63690
print(Quindio_Salento_Subject_Results_df)
print(Quindio_Salento_Subject_Results_df.shape)
# Out:
#                     ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  \
# ESTU_TIPODOCUMENTO
# NaN                               63690.0                    50
# NaN                               63690.0                    55
# NaN                               63690.0                    68
# NaN                               63690.0                    47
# NaN                               63690.0                    40
# ...                                   ...                   ...
# NaN                               63690.0                    56
# NaN                               63690.0                    68
# NaN                               63690.0                    45
# NaN                               63690.0                    51
# NaN                               63690.0                    63
#
#                     PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# ESTU_TIPODOCUMENTO
# NaN                               49                49
# NaN                               75                46
# NaN                               67                63
# NaN                               34                45
# NaN                               44                34
# ...                              ...               ...
# NaN                               46                39
# NaN                               61                59
# NaN                               52                48
# NaN                               34                41
# NaN                               50                48
#
#                     PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                                       50         55.0          250
# NaN                                       56         49.0          287
# NaN                                       67         55.0          327
# NaN                                       49         49.0          221
# NaN                                       29         44.0          187
# ...                                      ...          ...          ...
# NaN                                       56         40.0          243
# NaN                                       60         53.0          307
# NaN                                       44         56.0          240
# NaN                                       46         40.0          214
# NaN                                       60         43.0          272
#
# [86 rows x 7 columns]
# (86, 7)

# %%
Quindio_Salento_Subject_Results_df.describe()   # Score about Salento
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   86.0             86.000000         86.000000
# mean                 63690.0             52.313953         48.593023
# std                      0.0             10.552125         11.779721
# min                  63690.0             25.000000         22.000000
# 25%                  63690.0             45.000000         41.000000
# 50%                  63690.0             52.500000         48.500000
# 75%                  63690.0             59.000000         57.000000
# max                  63690.0             75.000000         75.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         86.000000                 86.000000    86.000000    86.000000
# mean          46.523256                 48.139535    44.930233   242.965116
# std            8.995066                 11.595296     9.315125    45.264828
# min           28.000000                 20.000000    29.000000   165.000000
# 25%           41.000000                 41.000000    38.000000   203.500000
# 50%           46.000000                 47.500000    44.000000   241.000000
# 75%           53.000000                 57.000000    50.750000   276.250000
# max           68.000000                 73.000000    73.000000   341.000000

# %% [markdown]
# # Average Score by Gender

# %% [markdown]
# ## Female

# %%
Gen = ['ESTU_GENERO', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Gender_Subject_df = Saber11_df[Gen]
F_Gender_Subject_Results_df = Gender_Subject_df.loc[(Gender_Subject_df['ESTU_GENERO'] == 'F')]  # Select female gender = F
print(F_Gender_Subject_Results_df)
print(F_Gender_Subject_Results_df.shape)
# Out:
#                    ESTU_GENERO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# ESTU_TIPODOCUMENTO
# NaN                          F                    54                65
# NaN                          F                    59                72
# NaN                          F                    37                48
# NaN                          F                    45                47
# NaN                          F                    43                45
# ...                        ...                   ...               ...
# NaN                          F                    62                53
# NaN                          F                    40                29
# NaN                          F                    55                48
# NaN                          F                    78                59
# NaN                          F                    58                51
#
#                     PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# ESTU_TIPODOCUMENTO
# NaN                               41                        33         55.0
# NaN                               63                        68         59.0
# NaN                               44                        32         43.0
# NaN                               55                        52         49.0
# NaN                               44                        39         36.0
# ...                              ...                       ...          ...
# NaN                               39                        54         51.0
# NaN                               33                        37         32.0
# NaN                               39                        43         44.0
# NaN                               62                        65         67.0
# NaN                               49                        52         48.0
#
#                     PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                         244
# NaN                         325
# NaN                         202
# NaN                         248
# NaN                         211
# ...                         ...
# NaN                         260
# NaN                         173
# NaN                         230
# NaN                         330
# NaN                         261
#
# [276572 rows x 7 columns]
# (276572, 7)

# %%
F_Gender_Subject_Results_df.describe()
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count         276572.000000     276572.000000     276572.000000
# mean              52.054760         49.680571         47.418904
# std               10.148094         11.308919         10.150748
# min                0.000000          0.000000          0.000000
# 25%               45.000000         42.000000         40.000000
# 50%               52.000000         49.000000         47.000000
# 75%               59.000000         57.000000         54.000000
# max              100.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES    PUNT_GLOBAL
# count             276572.000000  276378.000000  276572.000000
# mean                  47.833277      46.414722     245.143091
# std                   11.638367      11.044695      47.492473
# min                    0.000000       0.000000       0.000000
# 25%                   39.000000      39.000000     209.000000
# 50%                   47.000000      45.000000     241.000000
# 75%                   56.000000      51.000000     277.000000
# max                  100.000000     100.000000     492.000000

# %% [markdown]
# ## Male

# %%
M_Gender_Subject_Results_df = Gender_Subject_df.loc[(Gender_Subject_df['ESTU_GENERO'] == 'M')]  # Select male gender = M
print(M_Gender_Subject_Results_df)
print(M_Gender_Subject_Results_df.shape)
# Out:
#                    ESTU_GENERO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# ESTU_TIPODOCUMENTO
# NaN                          M                    57                43
# NaN                          M                    47                55
# NaN                          M                    58                45
# NaN                          M                    49                68
# NaN                          M                    64                57
# ...                        ...                   ...               ...
# NaN                          M                    47                29
# NaN                          M                    57                61
# NaN                          M                    60                58
# NaN                          M                    57                55
# NaN                          M                    69                57
#
#                     PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# ESTU_TIPODOCUMENTO
# NaN                               46                        49         33.0
# NaN                               46                        43         47.0
# NaN                               38                        40         35.0
# NaN                               50                        51         65.0
# NaN                               64                        67         73.0
# ...                              ...                       ...          ...
# NaN                               35                        37         34.0
# NaN                               62                        53         61.0
# NaN                               60                        51         45.0
# NaN                               40                        53         54.0
# NaN                               52                        56         52.0
#
#                     PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                         238
# NaN                         238
# NaN                         222
# NaN                         277
# NaN                         319
# ...                         ...
# NaN                         184
# NaN                         292
# NaN                         282
# NaN                         257
# NaN                         290
#
# [228292 rows x 7 columns]
# (228292, 7)

# %%
M_Gender_Subject_Results_df.describe()
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count         228292.000000     228292.000000     228292.000000
# mean              52.280325         52.642107         49.140504
# std               10.169633         11.844271         10.832714
# min                0.000000          0.000000          0.000000
# 25%               45.000000         44.000000         41.000000
# 50%               53.000000         53.000000         49.000000
# 75%               59.000000         61.000000         57.000000
# max              100.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES    PUNT_GLOBAL
# count             228292.000000  228152.000000  228292.000000
# mean                  48.719267      47.451348     252.228527
# std                   12.343772      11.604649      49.833117
# min                    0.000000       0.000000       0.000000
# 25%                   39.000000      39.000000     214.000000
# 50%                   48.000000      46.000000     250.000000
# 75%                   58.000000      53.000000     287.000000
# max                  100.000000     100.000000     500.000000

# %% [markdown]
# # Classification by Stratum

# %%
Saber11_df['FAMI_ESTRATOVIVIENDA'].unique() # Show stratum
# Out:
# array(['Estrato 2', 'Estrato 3', 'Estrato 1', 'Sin Estrato', 'Estrato 5',
#        'Estrato 6', 'Estrato 4', nan], dtype=object)

# %%
promedios = Saber11_df.groupby('FAMI_ESTRATOVIVIENDA')[['PUNT_LECTURA_CRITICA', 
                                                  'PUNT_MATEMATICAS', 
                                                  'PUNT_C_NATURALES', 
                                                  'PUNT_SOCIALES_CIUDADANAS', 
                                                  'PUNT_INGLES', 
                                                  'PUNT_GLOBAL']].mean().reset_index()


plt.figure(figsize=(12, 6))
promedios_melted = promedios.melt(id_vars='FAMI_ESTRATOVIVIENDA', 
                                   value_vars=['PUNT_LECTURA_CRITICA', 
                                               'PUNT_MATEMATICAS', 
                                               'PUNT_C_NATURALES', 
                                               'PUNT_SOCIALES_CIUDADANAS', 
                                               'PUNT_INGLES', 
                                               'PUNT_GLOBAL'], 
                                   var_name='Materia', 
                                   value_name='Promedio')

# Gráfica
sns.barplot(data=promedios_melted, x='FAMI_ESTRATOVIVIENDA', y='Promedio', hue='Materia')
plt.title('Promedios de Puntajes por Estrato de Vivienda')
plt.xlabel('Estrato de Vivienda')
plt.ylabel('Promedio de Puntajes')
plt.xticks(rotation=45)
plt.legend(title='Materia')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Performance of participants with different nationalities

# %%
print(Saber11_df['ESTU_NACIONALIDAD'].unique())    # Show all nationalities of participants
print('Total nationalities: ', len(Saber11_df['ESTU_NACIONALIDAD'].unique()))   # Show how many nationalities there are
# Out:
# ['SUIZA' 'VENEZUELA' 'COLOMBIA' 'ECUADOR' 'GUATEMALA' 'PERÚ'
#  'ESTADOS UNIDOS' 'MÉXICO' 'ITALIA' 'COREA DEL SUR' 'URUGUAY'
#  'ESTADOS FEDERADOS DE MICRONESIA' 'BOLIVIA' 'PANAMÁ' 'CHILE'
#  'REPÚBLICA DOMINICANA' 'EL SALVADOR' 'BRASIL' 'ARGENTINA' 'ESPAÑA'
#  'WALLIS Y FUTUNA' 'CABO VERDE' 'VANUATU' 'VIETNAM' 'FRANCIA' 'HONDURAS'
#  'CUBA' 'JAPÓN' 'ARABIA SAUDITA' 'RUSIA' 'HAITI' 'EGIPTO' 'IRÁN'
#  'REINO UNIDO' 'COSTA RICA' 'CHINA' 'LITUANIA' 'CURAZAO' 'ARUBA'
#  'PARAGUAY' 'NICARAGUA' 'ALEMANIA' 'CANADÁ' 'COREA DEL NORTE' 'TURQUÍA'
#  'PAÍSES BAJOS - HOLANDA' 'OMÁN']
# Total nationalities:  47

# %%
Nat = ['ESTU_NACIONALIDAD', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Nat_Subject_df = Saber11_df[Nat]
Ven_Nat_Subject_Results_df = Nat_Subject_df.loc[(Nat_Subject_df['ESTU_NACIONALIDAD'] == 'VENEZUELA')]  # Select Venezuela nationality
print(Ven_Nat_Subject_Results_df)
print(Ven_Nat_Subject_Results_df.shape)
# Out:
#                    ESTU_NACIONALIDAD  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# ESTU_TIPODOCUMENTO
# NaN                        VENEZUELA                    57                43
# NaN                        VENEZUELA                    59                72
# NaN                        VENEZUELA                    47                55
# NaN                        VENEZUELA                    43                43
# NaN                        VENEZUELA                    43                37
# ...                              ...                   ...               ...
# NaN                        VENEZUELA                    63                54
# NaN                        VENEZUELA                    42                41
# NaN                        VENEZUELA                    55                47
# NaN                        VENEZUELA                    50                46
# NaN                        VENEZUELA                    62                58
#
#                     PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# ESTU_TIPODOCUMENTO
# NaN                               46                        49         33.0
# NaN                               63                        68         59.0
# NaN                               46                        43         47.0
# NaN                               48                        42         43.0
# NaN                               37                        31         44.0
# ...                              ...                       ...          ...
# NaN                               45                        54         65.0
# NaN                               39                        41         48.0
# NaN                               57                        48         58.0
# NaN                               50                        33         60.0
# NaN                               56                        58         65.0
#
#                     PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                         238
# NaN                         325
# NaN                         238
# NaN                         220
# NaN                         188
# ...                         ...
# NaN                         274
# NaN                         207
# NaN                         261
# NaN                         230
# NaN                         295
#
# [2927 rows x 7 columns]
# (2927, 7)

# %%
Ven_Nat_Subject_Results_df.describe()   #Show the score for Venezuelans
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count           2927.000000       2927.000000       2927.000000
# mean              51.117526         48.582849         47.053297
# std                9.775218         11.288694         10.105690
# min                0.000000          0.000000          0.000000
# 25%               44.000000         41.000000         40.000000
# 50%               51.000000         48.000000         47.000000
# 75%               58.000000         56.000000         54.000000
# max               78.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count               2927.000000  2927.000000  2927.000000
# mean                  46.989067    45.965494   241.229587
# std                   11.162530    11.765967    45.865474
# min                    0.000000     0.000000     0.000000
# 25%                   39.000000    39.000000   207.000000
# 50%                   46.000000    44.000000   238.000000
# 75%                   55.000000    51.000000   272.000000
# max                  100.000000   100.000000   404.000000

# %%
Ven_Dep_df = Saber11_df[['ESTU_NACIONALIDAD', 'ESTU_COD_RESIDE_DEPTO']]
Ven_Dep_Tot = Ven_Dep_df.loc[(Ven_Dep_df['ESTU_NACIONALIDAD'] == 'VENEZUELA')]

Cont_Dep_Ven = Ven_Dep_Tot['ESTU_COD_RESIDE_DEPTO'].value_counts()

plt.figure(figsize=(10, 6))
Cont_Dep_Ven.plot(kind='bar')
plt.title('Distribution of Venezuelan students by department')
plt.xlabel('Department code')
plt.ylabel('Number of students')
plt.xticks(rotation=45)  
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ethnic Groups

# %%
Ethnic = ['ESTU_TIENEETNIA', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Ethnic_Subject_df = Saber11_df[Ethnic]
Ethnic_Yes_Subject_Results_df = Ethnic_Subject_df.loc[(Ethnic_Subject_df['ESTU_TIENEETNIA'] == 'Si')]  # Select Ethnic
print(Ethnic_Yes_Subject_Results_df)
print(Ethnic_Yes_Subject_Results_df.shape)
# Out:
#                    ESTU_TIENEETNIA  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# ESTU_TIPODOCUMENTO
# NaN                             Si                    54                57
# NaN                             Si                    54                43
# NaN                             Si                    51                37
# NaN                             Si                    51                44
# NaN                             Si                    37                38
# ...                            ...                   ...               ...
# NaN                             Si                    33                41
# NaN                             Si                    43                38
# NaN                             Si                    48                46
# NaN                             Si                    47                59
# NaN                             Si                    58                53
#
#                     PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# ESTU_TIPODOCUMENTO
# NaN                               31                        46         35.0
# NaN                               47                        46         46.0
# NaN                               51                        46         40.0
# NaN                               44                        37         45.0
# NaN                               42                        39         31.0
# ...                              ...                       ...          ...
# NaN                               38                        32         44.0
# NaN                               41                        49         40.0
# NaN                               33                        32         47.0
# NaN                               43                        42         45.0
# NaN                               39                        45         37.0
#
#                     PUNT_GLOBAL
# ESTU_TIPODOCUMENTO
# NaN                         230
# NaN                         237
# NaN                         229
# NaN                         220
# NaN                         192
# ...                         ...
# NaN                         183
# NaN                         213
# NaN                         202
# NaN                         238
# NaN                         239
#
# [31941 rows x 7 columns]
# (31941, 7)

# %%
Ethnic_Yes_Subject_Results_df.describe()
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count          31941.000000      31941.000000      31941.000000
# mean              46.062115         44.391691         42.509752
# std                9.758773         10.719052          9.221779
# min                0.000000          0.000000          0.000000
# 25%               39.000000         37.000000         36.000000
# 50%               45.000000         43.000000         41.000000
# 75%               53.000000         51.000000         48.000000
# max              100.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL
# count              31941.000000  31609.000000  31941.000000
# mean                  41.757240     41.730109    217.640149
# std                   10.501241      8.618526     42.646425
# min                    0.000000      0.000000      0.000000
# 25%                   34.000000     36.000000    185.000000
# 50%                   40.000000     40.000000    210.000000
# 75%                   48.000000     46.000000    243.000000
# max                  100.000000    100.000000    445.000000

# %%
Etn_Dep_df = Saber11_df[['ESTU_TIENEETNIA', 'ESTU_COD_RESIDE_DEPTO']]
Etn_Dep_Tot = Etn_Dep_df.loc[(Etn_Dep_df['ESTU_TIENEETNIA'] == 'Si')]

Cont_Dep_Etn = Etn_Dep_Tot['ESTU_COD_RESIDE_DEPTO'].value_counts()

plt.figure(figsize=(10, 6))
Cont_Dep_Etn.plot(kind='bar')
plt.title('Distribution of Ethnic Group students by department')
plt.xlabel('Department code')
plt.ylabel('Number of students')
plt.xticks(rotation=45)  
plt.show()
